# %%
# !git clone https://github.com/MyungKyuYi/AI-class.git
# Out:
# fatal: destination path 'AI-class' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
db = pd.read_csv("/content/AI-class/diabetes.csv")

# %%
db.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
cols=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin','BMI', 'DiabetesPedigreeFunction', 'Age','Outcome']
db = pd.read_csv("/content/AI-class/diabetes.csv", header=0, names=cols).dropna()


db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = db.drop(columns=["BMI","Outcome"])

y = db["BMI"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=None, random_state=42)

# %%
 from tensorflow.keras import layers, models

# %%
#x.shape[1]은 특징의 수 이다. -> 직접 특징의 수를 세어서 적어도 됨
#y.shape는 최종 분류할 때 클래스의  개수이다. -> 직접 분류할 클래스의 개수를 세어서 적어도 됨
from tensorflow.keras.optimizers import Adam # Adam 옵티마이저를 직접 import
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    #layers.Dropout(0.3),
    layers.Dense(64, activation="relu"),
    layers.Dense(1)   # 클래스 수 맞춤
])

model.compile(
    optimizer= "adam",
    loss="mse",   #회귀 문제이므로 mse 사용
    metrics=["mse"]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print(X.shape, y.shape)
# Out:
# (768, 7) (768,)

# %%
#검증 세트를 편리하게 만듬
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 404.7486 - mse: 404.7486 - val_loss: 69.2817 - val_mse: 69.2817
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 72.9111 - mse: 72.9111 - val_loss: 56.6832 - val_mse: 56.6832
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.9671 - mse: 60.9671 - val_loss: 50.8506 - val_mse: 50.8506
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.7328 - mse: 57.7328 - val_loss: 50.6721 - val_mse: 50.6721
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 52.4098 - mse: 52.4098 - val_loss: 48.8433 - val_mse: 48.8433
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.4360 - mse: 59.4360 - val_loss: 47.5268 - val_mse: 47.5268
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.2297 - mse: 40.2297 - val_loss: 51.9560 - val_mse: 51.9560
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.1827 - mse: 46.1827 - val_loss: 45.4939 - val_mse: 45.4939
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.0361 - mse: 43.0361 - val_loss: 45.3523 - val_mse: 45.3523
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.5008 - mse: 38.5008 - val_loss: 48.9322 - val_mse: 48.9322
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46.7066 - mse: 46.7066 - val_loss: 58.3095 - val_mse: 58.3095
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 44.2482 - mse: 44.2482 - val_loss: 43.0135 - val_mse: 43.0135
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 45.7737 - mse: 45.7737 - val_loss: 42.6123 - val_mse: 42.6123
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.1221 - mse: 38.1221 - val_loss: 46.1141 - val_mse: 46.1141
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.6938 - mse: 46.6938 - val_loss: 46.9258 - val_mse: 46.9258
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.7674 - mse: 46.7674 - val_loss: 44.1657 - val_mse: 44.1657
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 41.5579 - mse: 41.5579 - val_loss: 43.1669 - val_mse: 43.1669
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.6848 - mse: 40.6848 - val_loss: 48.3173 - val_mse: 48.3173
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 50.3596 - mse: 50.3596 - val_loss: 46.4225 - val_mse: 46.4225
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.6880 - mse: 45.6880 - val_loss: 46.9794 - val_mse: 46.9794
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.2134 - mse: 42.2134 - val_loss: 44.1990 - val_mse: 44.1990
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.1000 - mse: 36.1000 - val_loss: 49.5883 - val_mse: 49.5883
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.9455 - mse: 43.9455 - val_loss: 41.5574 - val_mse: 41.5574
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 48.8370 - mse: 48.8370 - val_loss: 54.5215 - val_mse: 54.5215
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 51.6138 - mse: 51.6138 - val_loss: 48.4725 - val_mse: 48.4725
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.2664 - mse: 38.2664 - val_loss: 42.2960 - val_mse: 42.2960
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.9895 - mse: 37.9895 - val_loss: 41.4958 - val_mse: 41.4958
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.8218 - mse: 44.8218 - val_loss: 47.0889 - val_mse: 47.0889
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.9476 - mse: 48.9476 - val_loss: 40.9251 - val_mse: 40.9251
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.8211 - mse: 37.8211 - val_loss: 41.0244 - val_mse: 41.0244
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.0444 - mse: 37.0444 - val_loss: 41.6081 - val_mse: 41.6081
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.3147 - mse: 35.3147 - val_loss: 44.5376 - val_mse: 44.5376
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.4173 - mse: 36.4173 - val_loss: 50.4044 - val_mse: 50.4044
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.1610 - mse: 49.1610 - val_loss: 46.4073 - val_mse: 46.4073
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.4780 - mse: 36.4780 - val_loss: 45.1887 - val_mse: 45.1887
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.1600 - mse: 38.1600 - val_loss: 43.7538 - val_mse: 43.7538
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.4452 - mse: 42.4452 - val_loss: 44.1386 - val_mse: 44.1386
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.9831 - mse: 33.9831 - val_loss: 42.5869 - val_mse: 42.5869
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 40.9293 - mse: 40.9293 - val_loss: 55.8715 - val_mse: 55.8715
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.8169 - mse: 36.8169 - val_loss: 49.4119 - val_mse: 49.4119
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 39.6078 - mse: 39.6078 - val_loss: 41.9770 - val_mse: 41.9770
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.6066 - mse: 46.6066 - val_loss: 42.2790 - val_mse: 42.2790
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.6988 - mse: 40.6988 - val_loss: 42.8033 - val_mse: 42.8033
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.0092 - mse: 51.0092 - val_loss: 42.1147 - val_mse: 42.1147
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.9916 - mse: 37.9916 - val_loss: 47.7841 - val_mse: 47.7841
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.0131 - mse: 36.0131 - val_loss: 44.1348 - val_mse: 44.1348
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.1947 - mse: 38.1947 - val_loss: 48.9815 - val_mse: 48.9815
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.7777 - mse: 40.7777 - val_loss: 46.2484 - val_mse: 46.2484
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 41.9896 - mse: 41.9896 - val_loss: 42.1894 - val_mse: 42.1894
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.8169 - mse: 49.8169 - val_loss: 68.1671 - val_mse: 68.1671

# %%
# 학습 곡선
loss = history.history['loss']
val_loss = history.history['val_loss']
mse = history.history['mse']
val_mse = history.history['val_mse']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)

# MSE 계산
mse = mean_squared_error(y_test, y_pred)

# MSE 출력
print(f"Mean Squared Error (MSE): {mse:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Mean Squared Error (MSE): 98.6608
